# %%
import pandas as pd

# %%
df = pd.read_csv('Spotify_Music.csv')

# %%
print(set(df["track_genre"]))
# Out:
# {'emo', 'dancehall', 'blues', 'malay', 'breakbeat', 'j-rock', 'grindcore', 'swedish', 'rockabilly', 'j-dance', 'punk-rock', 'country', 'punk', 'latino', 'mpb', 'disney', 'indie', 'electro', 'chill', 'acoustic', 'new-age', 'alt-rock', 'british', 'mandopop', 'drum-and-bass', 'honky-tonk', 'german', 'ambient', 'synth-pop', 'chicago-house', 'soul', 'psych-rock', 'latin', 'grunge', 'hardcore', 'j-idol', 'industrial', 'k-pop', 'hip-hop', 'minimal-techno', 'sad', 'dub', 'piano', 'death-metal', 'classical', 'alternative', 'show-tunes', 'rock', 'r-n-b', 'trip-hop', 'comedy', 'disco', 'pop-film', 'bluegrass', 'turkish', 'funk', 'singer-songwriter', 'guitar', 'party', 'black-metal', 'romance', 'children', 'afrobeat', 'metal', 'happy', 'deep-house', 'opera', 'sleep', 'trance', 'forro', 'techno', 'kids', 'dubstep', 'j-pop', 'hard-rock', 'garage', 'reggae', 'reggaeton', 'jazz', 'rock-n-roll', 'metalcore', 'groove', 'french', 'goth', 'house', 'hardstyle', 'salsa', 'world-music', 'iranian', 'ska', '
# ...
